# %%
import pandas as pd
from utils import get_best, prepare_ratings, remove_players
from formations import angeball_v3, perfect_alonso
remove=["Gabriel", "Endrick", "Gabriel Jesus", "Éder Militão", "Rodrygo", "Vitor Reis"]
ratings_raw = pd.read_excel("data/FM24_Carreer1.xlsx", sheet_name="brazil_mar_2027")
alonso_ratings = prepare_ratings(ratings_raw, formation=perfect_alonso)
alonso_ratings = remove_players(alonso_ratings, remove)
alonso1, alonso1score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)

alonso_ratings = remove_players(alonso_ratings, [player["name"] for player in alonso1])
alonso2, alonso2score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)

alonso_ratings = remove_players(alonso_ratings, [player["name"] for player in alonso2])
alonso3, alonso3score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /root/anaconda3/envs/learn/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/502e3e3852ef4ca5b53aa8acf4520bc8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/502e3e3852ef4ca5b53aa8acf4520bc8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 153 COLUMNS
# At line 10234 RHS
# At line 10383 BOUNDS
# At line 11644 ENDATA
# Problem MODEL has 148 rows, 1260 columns and 6300 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 164.911 - 0.01 seconds
# Cgl0004I processed model has 138 rows, 1260 columns (1260 integer (1260 of which binary)) and 5040 elements
# Cutoff increment increased from 1e-05 to 0.0999
# Cbc0038I Initial state - 8 integers unsatisfied sum - 3.55556
# Cbc0038I Pass   1: suminf.    0.50000 (2) obj. -164.4 iterations 18
# ...

# %%
alonso1
# Out:
# [{'name': 'Edson Bordon', 'position': 'rps'},
#  {'name': 'Andrey Santos', 'position': 'wcbs'},
#  {'name': 'Roger Ibañez', 'position': 'wcbd'},
#  {'name': 'João Pedro', 'position': 'aps'},
#  {'name': 'Vanderson', 'position': 'wbs'},
#  {'name': 'Vanderlan', 'position': 'wbs'},
#  {'name': 'Joelinton', 'position': 'dms'},
#  {'name': 'Vinícius Júnior', 'position': 'f9s'},
#  {'name': 'Gabriel Martinelli', 'position': 'ssa'},
#  {'name': 'Ederson', 'position': 'sks'},
#  {'name': 'Gio', 'position': 'bpdd'}]

# %%
alonso2
# Out:
# [{'name': 'Evertow', 'position': 'wcbs'},
#  {'name': 'Marco Aurélio', 'position': 'wbs'},
#  {'name': 'Mateus Iseppe', 'position': 'f9s'},
#  {'name': 'Bremer', 'position': 'wcbd'},
#  {'name': 'Danilo', 'position': 'wbs'},
#  {'name': 'Natan', 'position': 'bpdd'},
#  {'name': 'Antony', 'position': 'aps'},
#  {'name': 'Marcos Leonardo', 'position': 'ssa'},
#  {'name': 'Marquinhos', 'position': 'dms'},
#  {'name': 'Bruno Guimarães', 'position': 'rps'},
#  {'name': 'Alisson', 'position': 'sks'}]

# %%
players = [
    # "Edson Bordon" ,
 "Andrey Santos" ,
 "Roger Ibañez" ,
 "João Pedro" ,
 "Vanderson" ,
 "Vanderlan" ,
#  "Joelinton" ,
#  "Vinícius Júnior" ,
 "Ederson" ,
 "Gio" ,
 "Evertow" ,
 "Marco Aurélio" ,
 "Mateus Iseppe" ,
 "Bremer" ,
 "Danilo" ,
 "Natan" ,
 "Marcos Leonardo" ,
 "Marquinhos" ,
#  "Bruno Guimarães" ,
 "Alisson" ,
 "Andrew",
 "Vitor Roque",
 "Vitor Reis"
]

# %%
import pandas as pd
from utils import get_best, prepare_ratings, remove_players
from formations import angeball_v3, perfect_alonso

ratings_raw = pd.read_excel("data/FM24_Carreer1.xlsx", sheet_name="brazil_mar_2027")
ratings_raw = ratings_raw.query("Name in @players")

alonso_ratings = prepare_ratings(ratings_raw, formation=perfect_alonso)
alonso1, alonso1score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)

alonso_ratings = remove_players(alonso_ratings, [player["name"] for player in alonso1])
alonso2, alonso2score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)

alonso_ratings = remove_players(alonso_ratings, [player["name"] for player in alonso2])
alonso3, alonso3score = get_best(alonso_ratings, perfect_alonso, age_constraint=26)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /root/anaconda3/envs/learn/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8ce4b49b94474528a8582afd08c46159-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/8ce4b49b94474528a8582afd08c46159-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 47 COLUMNS
# At line 1648 RHS
# At line 1691 BOUNDS
# At line 1892 ENDATA
# Problem MODEL has 42 rows, 200 columns and 1000 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 160.725 - 0.03 seconds
# Cgl0004I processed model has 32 rows, 200 columns (200 integer (200 of which binary)) and 800 elements
# Cutoff increment increased from 1e-05 to 0.0999
# Cbc0038I Initial state - 6 integers unsatisfied sum - 2.25
# Cbc0038I Solution found of -160.5
# ...

# %%
alonso1
# Out:
# [{'name': 'Andrey Santos', 'position': 'wcbs'},
#  {'name': 'Mateus Iseppe', 'position': 'f9s'},
#  {'name': 'Roger Ibañez', 'position': 'bpdd'},
#  {'name': 'João Pedro', 'position': 'aps'},
#  {'name': 'Danilo', 'position': 'rps'},
#  {'name': 'Vanderson', 'position': 'wbs'},
#  {'name': 'Marcos Leonardo', 'position': 'ssa'},
#  {'name': 'Vanderlan', 'position': 'wbs'},
#  {'name': 'Marquinhos', 'position': 'dms'},
#  {'name': 'Ederson', 'position': 'sks'},
#  {'name': 'Gio', 'position': 'wcbd'}]
